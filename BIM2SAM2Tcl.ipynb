# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# 2.9.2

# %%
# %cd /content

# !git clone https://github.com/LiniXiang/BIM2SAM.AI.git
# Out:
# /content
# Cloning into 'BIM2SAM.AI'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 170 (delta 12), reused 0 (delta 0), pack-reused 136
# Receiving objects: 100% (170/170), 3.45 MiB | 17.67 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# %cd /content/BIM2SAM.AI/Python/NeuralNets
# !python BIM2FeaturesNN_V1.py
# Out:
# /content/BIM2SAM.AI/Python/NeuralNets
# 2.9.2
#     height  ...        fc
# 46   39.60  ...  4.300000
# 47   39.60  ...  3.800000
# 48   39.60  ...  3.600000
# 49   39.37  ...  3.625816
# 50   19.69  ...  3.190718
#
# [5 rows x 5 columns]
#           Ap  ...   N
# 46  0.140603  ...  10
# 47  0.140603  ...  10
# 48  0.072159  ...  10
# 49  0.366941  ...  10
# 50  0.140603  ...   9
#
# [5 rows x 5 columns]
#     height  ...   N
# 46   39.60  ...  10
# 47   39.60  ...  10
# 48   39.60  ...  10
# 49   39.37  ...  10
# 50   19.69  ...   9
#
# [5 rows x 10 columns]
#            count  ...          max
# height      41.0  ...   176.000000
# length      41.0  ...   120.000000
# thickness   41.0  ...     8.000000
# E           41.0  ...  5769.432089
# fc          41.0  ...    10.245105
#
# [5 rows x 8 columns]
# 2022-11-12 05:41:37.105651: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1536
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 26,629
# Trainable params: 26,629
# Non-trainable params: 0
# _________________________________________________________________
# 0
# ....................................................................................................100
# ....................................................................................................200
# ....................................................................................................300
# ....................................................................................................400
# ....................................................................................................500
# ....................................................................................................600
# ....................................................................................................700
# ....................................................................................................800
# ....................................................................................................900
# ....................................................................................................1000
# ....................................................................................................1100
# ....................................................................................................1200
# ....................................................................................................1300
# ..............................................................................
#
#           loss  ...  epoch
# 1373  0.609696  ...   1373
# 1374  0.609379  ...   1374
# 1375  0.609085  ...   1375
# 1376  0.608780  ...   1376
# 1377  0.608527  ...   1377
#
# [5 rows x 7 columns]
# Testing set Mean Abs Error:  0.81 Ap+An+Bn+beta+N
# Saved model to disk
# 1/1 [==============================] - 0s 76ms/step
# Figure(1250x1250)
# Figure(640x480)
# Figure(2000x1000)
# Closing remaining open files:../../Data/NeuralNets/DataStats_ContinuumWall_V1.h5...done

# %%
# %cd /usr/local
# !wget http://ftp.gnu.org/gnu/glibc/glibc-2.29.tar.gz
# Out:
# /usr/local
# --2022-11-12 05:12:24--  http://ftp.gnu.org/gnu/glibc/glibc-2.29.tar.gz
# Resolving ftp.gnu.org (ftp.gnu.org)... 209.51.188.20, 2001:470:142:3::b
# Connecting to ftp.gnu.org (ftp.gnu.org)|209.51.188.20|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32592893 (31M) [application/x-gzip]
# Saving to: ‘glibc-2.29.tar.gz’
#
# glibc-2.29.tar.gz   100%[===================>]  31.08M  6.80MB/s    in 4.6s
#
# 2022-11-12 05:12:30 (6.80 MB/s) - ‘glibc-2.29.tar.gz’ saved [32592893/32592893]

# %%
# !sudo su
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# a - pthread_setspecific.os
# a - pthread_sigmask.os
# a - pthread_kill.os
# a - pthread_sigqueue.os
# a - pthread_cancel.os
# a - pthread_testcancel.os
# a - pthread_setcancelstate.os
# a - pthread_setcanceltype.os
# a - pthread_once.os
# a - old_pthread_atfork.os
# a - pthread_getcpuclockid.os
# a - pthread_clock_gettime.os
# a - pthread_clock_settime.os
# a - shm-directory.os
# a - sem_init.os
# a - sem_destroy.os
# a - sem_open.os
# a - sem_close.os
# a - sem_unlink.os
# a - sem_getvalue.os
# a - sem_wait.os
# a - sem_timedwait.os
# a - sem_post.os
# a - cleanup.os
# a - cleanup_defer.os
# a - cleanup_compat.os
# a - cleanup_defer_compat.os
# a - unwind.os
# a - pt-longjmp.os
# a - pt-cleanup.os
# a - cancellation.os
# a - lowlevellock.os
# a - lll_timedlock_wait.os
# a - lll_timedwait_tid.os
# a - pt-fork.os
# a - pt-vfork.os
# a - pt-fcntl.os
# a - write.os
# a - read.os
# a - close.os
# a - accept.os
# a - connect.os
# a - recv.os
# a - recvfrom.os
# a - send.os
# a - sendto.os
# a - fsync.os
# a - lseek.os
# a - lseek64.os
# a - msync.os
# a - nanosleep.os
# a - open.os
# a - open64.os
# a - pause.os
# a - pread.os
# a - pread64.os
# a - pwrite.os
# a - pwrite64.os
# a - tcdrain.os
# a - wait.os
# a - waitpid.os
# a - msgrcv.os
# a - msgsnd.os
# a - sigwait.os
# a - sigsuspend.os
# a - recvmsg.os
# a - sendmsg.os
# a - pt-raise.os
# a - pt-system.os
# a - flockfile.os
# a - ftrylockfile.os
# a - funlockfile.os
# a - sigaction.os
# a - herrno.os
# a - res.os
# a - pt-allocrtsig.os
# a - pthread_kill_other_threads.os
# a - pthread_getaffinity.os
# a - pthread_setaffinity.os
# a - pthread_attr_getaffinity.os
# a - pthread_attr_setaffinity.os
# a - pthread_mutexattr_getrobust.os
# a - pthread_mutexattr_setrobust.os
# a - pthread_mutex_consistent.os
# a - cleanup_routine.os
# a - unwind-forcedunwind.os
# a - pthread_mutexattr_getprotocol.os
# a - pthread_mutexattr_setprotocol.os
# a - pthread_mutexattr_getprioceiling.os
# a - pthread_mutexattr_setprioceiling.os
# a - tpp.os
# a - pthread_mutex_getprioceiling.os
# a - pthread_mutex_setprioceiling.os
# a - pthread_setname.os
# a - pthread_getname.os
# a - pthread_setattr_default_np.os
# a - pthread_getattr_default_np.os
# a - thrd_create.os
# a - thrd_detach.os
# a - thrd_exit.os
# a - thrd_join.os
# a - mtx_destroy.os
# a - mtx_init.os
# a - mtx_lock.os
# a - mtx_timedlock.os
# a - mtx_trylock.os
# a - mtx_unlock.os
# a - call_once.os
# a - cnd_broadcast.os
# a - cnd_destroy.os
# a - cnd_init.os
# a - cnd_signal.os
# a - cnd_timedwait.os
# a - cnd_wait.os
# a - tss_create.os
# a - tss_delete.os
# a - tss_get.os
# a - tss_set.os
# a - pthread_mutex_conf.os
# a - elision-lock.os
# a - elision-unlock.os
# a - elision-timed.os
# a - elision-trylock.os
# a - errno-loc.os
# gcc   -shared -static-libgcc -Wl,-O1  -Wl,-z,defs -Wl,-dynamic-linker=/usr/local/lib/ld-linux-x86-64.so.2 -B/usr/local/glibc-2.29/build/nptl/ -B/usr/local/glibc-2.29/build/csu/ -B/usr/local/glibc-2.29/build/nptl/ -Wl,--version-script=/usr/local/glibc-2.29/build/libpthread.map -Wl,-soname=libpthread.so.0 -Wl,-z,combreloc -Wl,-z,relro -Wl,--hash-style=both  -Wl,--enable-new-dtags,-z,nodelete,-z,initfirst -e __nptl_main -L/usr/local/glibc-2.29/build -L/usr/local/glibc-2.29/build/math -L/usr/local/glibc-2.29/build/elf -L/usr/local/glibc-2.29/build/dlfcn -L/usr/local/glibc-2.29/build/nss -L/usr/local/glibc-2.29/build/nis -L/usr/local/glibc-2.29/build/rt -L/usr/local/glibc-2.29/build/resolv -L/usr/local/glibc-2.29/build/mathvec -L/usr/local/glibc-2.29/build/support -L/usr/local/glibc-2.29/build/crypt -L/usr/local/glibc-2.29/build/nptl -Wl,-rpath-link=/usr/local/glibc-2.29/build:/usr/local/glibc-2.29/build/math:/usr/local/glibc-2.29/build/elf:/usr/local/glibc-2.29/build/dlfcn:/usr/local/glibc-2.29/build/nss:/usr/local/glibc-2.29/build/nis:/usr/local/glibc-2.29/build/rt:/usr/local/glibc-2.29/build/resolv:/usr/local/glibc-2.29/build/mathvec:/usr/local/glibc-2.29/build/support:/usr/local/glibc-2.29/build/crypt:/usr/local/glibc-2.29/build/nptl -o /usr/local/glibc-2.29/build/nptl/libpthread.so -T /usr/local/glibc-2.29/build/shlib.lds /usr/local/glibc-2.29/build/csu/abi-note.o -Wl,--whole-archive /usr/local/glibc-2.29/build/nptl/libpthread_pic.a -Wl,--no-whole-archive   -Wl,--start-group /usr/local/glibc-2.29/build/libc.so /usr/local/glibc-2.29/build/libc_nonshared.a -Wl,--as-needed /usr/local/glibc-2.29/build/elf/ld.so -Wl,--no-as-needed -Wl,--end-group
# mv -f /usr/local/glibc-2.29/build/nptl/nptl_lock_constants.py.tmp /usr/local/glibc-2.29/build/nptl/nptl_lock_constants.py
# rm -f /usr/local/glibc-2.29/build/nptl/libpthread.so.0.new
# /bin/sh ../scripts/rellns-sh /usr/local/glibc-2.29/build/nptl/libpthread.so /usr/local/glibc-2.29/build/nptl/libpthread.so.0.new
# mv -f /usr/local/glibc-2.29/build/nptl/libpthread.so.0.new /usr/local/glibc-2.29/build/nptl/libpthread.so.0
# make[2]: Leaving directory '/usr/local/glibc-2.29/nptl'
# make  subdir=rt -C rt ..=../ others
# make[2]: Entering directory '/usr/local/glibc-2.29/rt'
# gcc ../sysdeps/pthread/aio_cancel.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_cancel.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_cancel.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_cancel.o
# gcc ../sysdeps/pthread/aio_error.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_error.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_error.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_error.o
# gcc ../sysdeps/pthread/aio_fsync.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_fsync.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_fsync.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_fsync.o
# gcc ../sysdeps/pthread/aio_misc.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_misc.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_misc.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_misc.o
# gcc ../sysdeps/unix/sysv/linux/wordsize-64/aio_read.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_read.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_read.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_read.o
# gcc ../sysdeps/unix/sysv/linux/wordsize-64/aio_read64.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_read64.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_read64.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_read64.o
# gcc aio_return.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_return.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_return.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_return.o
# gcc ../sysdeps/pthread/aio_suspend.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno    -fexceptions     -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_suspend.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_suspend.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_suspend.o
# gcc ../sysdeps/unix/sysv/linux/wordsize-64/aio_write.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_write.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_write.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_write.o
# gcc ../sysdeps/unix/sysv/linux/wordsize-64/aio_write64.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_write64.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_write64.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_write64.o
# gcc ../sysdeps/unix/sysv/linux/wordsize-64/lio_listio.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/lio_listio.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/lio_listio.o.dt -MT /usr/local/glibc-2.29/build/rt/lio_listio.o
# gcc ../sysdeps/unix/sysv/linux/wordsize-64/lio_listio64.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/lio_listio64.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/lio_listio64.o.dt -MT /usr/local/glibc-2.29/build/rt/lio_listio64.o
# gcc ../sysdeps/unix/sysv/linux/aio_sigqueue.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_sigqueue.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_sigqueue.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_sigqueue.o
# gcc ../sysdeps/pthread/aio_notify.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/aio_notify.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/aio_notify.o.dt -MT /usr/local/glibc-2.29/build/rt/aio_notify.o
# gcc ../sysdeps/unix/sysv/linux/x86_64/timer_create.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/timer_create.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/timer_create.o.dt -MT /usr/local/glibc-2.29/build/rt/timer_create.o
# gcc ../sysdeps/unix/sysv/linux/x86_64/timer_delete.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/timer_delete.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/timer_delete.o.dt -MT /usr/local/glibc-2.29/build/rt/timer_delete.o
# gcc ../sysdeps/unix/sysv/linux/x86_64/timer_getoverr.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/timer_getoverr.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/timer_getoverr.o.dt -MT /usr/local/glibc-2.29/build/rt/timer_getoverr.o
# gcc ../sysdeps/unix/sysv/linux/x86_64/timer_gettime.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/timer_gettime.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/timer_gettime.o.dt -MT /usr/local/glibc-2.29/build/rt/timer_gettime.o
# gcc ../sysdeps/unix/sysv/linux/x86_64/timer_settime.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/timer_settime.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/timer_settime.o.dt -MT /usr/local/glibc-2.29/build/rt/timer_settime.o
# gcc ../sysdeps/posix/shm_open.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/shm_open.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/shm_open.o.dt -MT /usr/local/glibc-2.29/build/rt/shm_open.o
# gcc ../sysdeps/posix/shm_unlink.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/shm_unlink.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/shm_unlink.o.dt -MT /usr/local/glibc-2.29/build/rt/shm_unlink.o
# gcc ../sysdeps/unix/sysv/linux/mq_open.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/mq_open.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/mq_open.o.dt -MT /usr/local/glibc-2.29/build/rt/mq_open.o
# gcc ../sysdeps/unix/sysv/linux/mq_close.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/mq_close.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/mq_close.o.dt -MT /usr/local/glibc-2.29/build/rt/mq_close.o
# gcc ../sysdeps/unix/sysv/linux/mq_unlink.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/mq_unlink.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/mq_unlink.o.dt -MT /usr/local/glibc-2.29/build/rt/mq_unlink.o
# gcc ../sysdeps/unix/sysv/linux/mq_getattr.c -c -std=gnu11 -fgnu89-inline  -g -O2 -Wall -Wwrite-strings -Wundef -Werror -fmerge-all-constants -frounding-math -fno-stack-protector -Wstrict-prototypes -Wold-style-definition -fmath-errno         -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -o /usr/local/glibc-2.29/build/rt/mq_getattr.o -MD -MP -MF /usr/local/glibc-2.29/build/rt/mq_getattr.o.dt -MT /usr/local/glibc-2.29/build/rt/mq_getattr.o
# (echo '#define SYSCALL_NAME mq_getsetattr'; \
#  echo '#define SYSCALL_NARGS 3'; \
#  echo '#define SYSCALL_SYMBOL mq_setattr'; \
#  echo '#define SYSCALL_NOERRNO 0'; \
#  echo '#define SYSCALL_ERRVAL 0'; \
#  echo '#include <syscall-template.S>'; \
# ) | gcc -c  -U_FORTIFY_SOURCE   -I../include -I/usr/local/glibc-2.29/build/rt  -I/usr/local/glibc-2.29/build  -I../sysdeps/unix/sysv/linux/x86_64/64  -I../sysdeps/unix/sysv/linux/x86_64  -I../sysdeps/unix/sysv/linux/x86/include -I../sysdeps/unix/sysv/linux/x86  -I../sysdeps/x86/nptl  -I../sysdeps/unix/sysv/linux/wordsize-64  -I../sysdeps/x86_64/nptl  -I../sysdeps/unix/sysv/linux/include -I../sysdeps/unix/sysv/linux  -I../sysdeps/nptl  -I../sysdeps/pthread  -I../sysdeps/gnu  -I../sysdeps/unix/inet  -I../sysdeps/unix/sysv  -I../sysdeps/unix/x86_64  -I../sysdeps/unix  -I../sysdeps/posix  -I../sysdeps/x86_64/64  -I../sysdeps/x86_64/fpu/multiarch  -I../sysdeps/x86_64/fpu  -I../sysdeps/x86/fpu/include -I../sysdeps/x86/fpu  -I../sysdeps/x86_64/multiarch  -I../sysdeps/x86_64  -I../sysdeps/x86  -I../sysdeps/ieee754/float128  -I../sysdeps/ieee754/ldbl-96/include -I../sysdeps/ieee754/ldbl-96  -I../sysdeps/ieee754/dbl-64/wordsize-64  -I../sysdeps/ieee754/dbl-64  -I../sysdeps/ieee754/flt-32  -I../sysdeps/wordsize-64  -I../sysdeps/ieee754  -I../sysdeps/generic  -I.. -I../libio -I.   -D_LIBC_REENTRANT -include /usr/local/glibc-2.29/build/libc-modules.h -DMODULE_NAME=librt -include ../include/libc-symbols.h  -DPIC     -DTOP_NAMESPACE=glibc -DASSEMBLER  -g -Werror=undef -Wa,--noexecstack   -o /usr/local/glibc-2.29/build/rt/mq_setattr.o -x assembler-with-cpp - -MD -MP -MF /usr/local/glibc-2.29/build/rt/mq_setattr.o.dt -MT /usr/local/glibc-2.29/build/rt/mq_setattr.o
# ...
# (cd /usr/local/glibc-2.29/build/nscd/.; objdump -h nscd_getpw_r.o nscd_getgr_r.o nscd_gethst_r.o nscd_getai.o nscd_initgroups.o nscd_getserv_r.o nscd_netgroup.o nscd_helper.o nscd_getpw_r.os nscd_getgr_r.os nscd_gethst_r.os nscd_getai.os nscd_initgroups.os nscd_getserv_r.os nscd_netgroup.os nscd_helper.os nscd.o connections.o pwdcache.o getpwnam_r.o getpwuid_r.o grpcache.o getgrnam_r.o getgrgid_r.o hstcache.o gethstbyad_r.o gethstbynm3_r.o getsrvbynm_r.o getsrvbypt_r.o servicescache.o dbg_log.o nscd_conf.o nscd_stat.o cache.o mem.o nscd_setup_thread.o xmalloc.o xstrdup.o aicache.o initgrcache.o gai.o res_hconf.o netgroupcache.o) | \
# gawk '/\.gnu\.glibc-stub\./ { \
# 	  sub(/\.gnu\.glibc-stub\./, "", $2); \
# 	  stubs[$2] = 1; } \
# 	END { for (s in stubs) print "#define __stub_" s }' > /usr/local/glibc-2.29/build/nscd/stubsT
# mv -f /usr/local/glibc-2.29/build/nscd/stubsT /usr/local/glibc-2.29/build/nscd/stubs
# make[2]: Leaving directory '/usr/local/glibc-2.29/nscd'
# make  subdir=streams -C streams ..=../ subdir_install
# make[2]: Entering directory '/usr/local/glibc-2.29/streams'
# /usr/bin/install -c -m 644 stropts.h /usr/local/include/stropts.h
# /usr/bin/install -c -m 644 sys/stropts.h /usr/local/include/sys/stropts.h
# /usr/bin/install -c -m 644 ../bits/stropts.h /usr/local/include/bits/stropts.h
# /usr/bin/install -c -m 644 ../sysdeps/x86/bits/xtitypes.h /usr/local/include/bits/xtitypes.h
# /usr/bin/install -c -m 644 /usr/local/glibc-2.29/build/gnu/lib-names-64.h /usr/local/include/gnu/lib-names-64.h
# (cd /usr/local/glibc-2.29/build/streams/.; objdump -h isastream.o getmsg.o getpmsg.o putmsg.o putpmsg.o fattach.o fdetach.o isastream.os getmsg.os getpmsg.os putmsg.os putpmsg.os fattach.os fdetach.os) | \
# gawk '/\.gnu\.glibc-stub\./ { \
# 	  sub(/\.gnu\.glibc-stub\./, "", $2); \
# 	  stubs[$2] = 1; } \
# 	END { for (s in stubs) print "#define __stub_" s }' > /usr/local/glibc-2.29/build/streams/stubsT
# mv -f /usr/local/glibc-2.29/build/streams/stubsT /usr/local/glibc-2.29/build/streams/stubs
# make[2]: Leaving directory '/usr/local/glibc-2.29/streams'
# make  subdir=login -C login ..=../ subdir_install
# make[2]: Entering directory '/usr/local/glibc-2.29/login'
# /usr/bin/install -c -m 644 utmp.h /usr/local/include/utmp.h
# /usr/bin/install -c -m 644 ../sysdeps/gnu/bits/utmp.h /usr/local/include/bits/utmp.h
# /usr/bin/install -c -m 644 lastlog.h /usr/local/include/lastlog.h
# /usr/bin/install -c -m 644 pty.h /usr/local/include/pty.h
# /usr/bin/install -c -m 644 ../sysdeps/gnu/utmpx.h /usr/local/include/utmpx.h
# /usr/bin/install -c -m 644 ../sysdeps/gnu/bits/utmpx.h /usr/local/include/bits/utmpx.h
# /usr/bin/install -c /usr/local/glibc-2.29/build/login/libutil.so /usr/local/lib/libutil-2.29.so.new
# mv -f /usr/local/lib/libutil-2.29.so.new /usr/local/lib/libutil-2.29.so
# echo `../scripts/rellns-sh -p /usr/local/lib/libutil-2.29.so /usr/local/lib/libutil.so.1` /usr/local/lib/libutil.so.1 >> /usr/local/glibc-2.29/build/elf/symlink.list
# rm -f /usr/local/lib/libutil.so.new
# /bin/sh ../scripts/rellns-sh /usr/local/lib/libutil.so.1 /usr/local/lib/libutil.so.new
# mv -f /usr/local/lib/libutil.so.new /usr/local/lib/libutil.so
# /usr/bin/install -c -m 644 /usr/local/glibc-2.29/build/login/libutil.a /usr/local/lib/libutil.a
# /usr/bin/install -c -m 644 /usr/local/glibc-2.29/build/gnu/lib-names-64.h /usr/local/include/gnu/lib-names-64.h
# (cd /usr/local/glibc-2.29/build/login/.; objdump -h getlogin.o getlogin_r.o setlogin.o getlogin_r_chk.o getutent.o getutent_r.o getutid.o getutline.o getutid_r.o getutline_r.o utmp_file.o utmpname.o updwtmp.o getpt.o grantpt.o unlockpt.o ptsname.o ptsname_r_chk.o setutxent.o getutxent.o endutxent.o getutxid.o getutxline.o pututxline.o utmpxname.o updwtmpx.o getutmpx.o getutmp.o getlogin.os getlogin_r.os setlogin.os getlogin_r_chk.os getutent.os getutent_r.os getutid.os getutline.os getutid_r.os getutline_r.os utmp_file.os utmpname.os updwtmp.os getpt.os grantpt.os unlockpt.os ptsname.os ptsname_r_chk.os setutxent.os getutxent.os endutxent.os getutxid.os getutxline.os pututxline.os utmpxname.os updwtmpx.os getutmpx.os getutmp.os login.o login_tty.o logout.o logwtmp.o openpty.o forkpty.o login.os login_tty.os logout.os logwtmp.os openpty.os forkpty.os) | \
# gawk '/\.gnu\.glibc-stub\./ { \
# 	  sub(/\.gnu\.glibc-stub\./, "", $2); \
# 	  stubs[$2] = 1; } \
# 	END { for (s in stubs) print "#define __stub_" s }' > /usr/local/glibc-2.29/build/login/stubsT
# mv -f /usr/local/glibc-2.29/build/login/stubsT /usr/local/glibc-2.29/build/login/stubs
# make[2]: Leaving directory '/usr/local/glibc-2.29/login'
# make  subdir=elf -C elf ..=../ subdir_install
# make[2]: Entering directory '/usr/local/glibc-2.29/elf'
# /usr/bin/install -c -m 644 elf.h /usr/local/include/elf.h
# /usr/bin/install -c -m 644 ../bits/elfclass.h /usr/local/include/bits/elfclass.h
# /usr/bin/install -c -m 644 link.h /usr/local/include/link.h
# /usr/bin/install -c -m 644 ../sysdeps/x86/bits/link.h /usr/local/include/bits/link.h
# /usr/bin/install -c -m 644 /usr/local/glibc-2.29/build/gnu/lib-names-64.h /usr/local/include/gnu/lib-names-64.h
# make -f /usr/local/glibc-2.29/build/elf/librtld.mk -f rtld-Rules
# make[3]: Entering directory '/usr/local/glibc-2.29/elf'
# make subdir=csu -C ../csu ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-check_fds.os rtld-errno.os'
# make subdir=dirent -C ../dirent ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-closedir.os rtld-rewinddir.os rtld-readdir64.os rtld-fdopendir.os rtld-getdents64.os'
# make subdir=elf -C ../elf ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-dl-addr-obj.os'
# make[4]: Entering directory '/usr/local/glibc-2.29/elf'
# make[4]: Leaving directory '/usr/local/glibc-2.29/elf'
# make subdir=gmon -C ../gmon ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-profil.os rtld-prof-freq.os'
# make subdir=io -C ../io ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-xstat.os rtld-fxstat.os rtld-lxstat.os rtld-lseek64.os rtld-access.os rtld-close_nocancel.os rtld-fcntl_nocancel.os rtld-open64_nocancel.os rtld-openat64_nocancel.os rtld-read_nocancel.os rtld-write_nocancel.os'
# make subdir=malloc -C ../malloc ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-scratch_buffer_set_array_size.os'
# make[4]: Entering directory '/usr/local/glibc-2.29/malloc'
# make[4]: Leaving directory '/usr/local/glibc-2.29/malloc'
# make subdir=misc -C ../misc ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-mmap64.os rtld-munmap.os rtld-mprotect.os'
# make subdir=nptl -C ../nptl ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-libc-lowlevellock.os rtld-libc_multiple_threads.os'
# make[4]: Entering directory '/usr/local/glibc-2.29/nptl'
# make[4]: Leaving directory '/usr/local/glibc-2.29/nptl'
# make subdir=posix -C ../posix ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-uname.os rtld-_exit.os rtld-getpid.os rtld-environ.os'
# make[4]: Entering directory '/usr/local/glibc-2.29/posix'
# make[4]: Leaving directory '/usr/local/glibc-2.29/posix'
# make subdir=setjmp -C ../setjmp ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-setjmp.os rtld-__longjmp.os'
# make subdir=signal -C ../signal ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-sigaction.os'
# make subdir=string -C ../string ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-strchr.os rtld-strcmp.os rtld-strcspn.os rtld-strdup.os rtld-strlen.os rtld-strnlen.os rtld-strncmp.os rtld-memchr.os rtld-memcmp.os rtld-memmove.os rtld-memset.os rtld-mempcpy.os rtld-stpcpy.os rtld-memcpy.os rtld-rawmemchr.os rtld-strcmp-sse2.os rtld-strcmp-sse2-unaligned.os rtld-strcmp-ssse3.os rtld-strcmp-avx2.os rtld-strncmp-sse2.os rtld-strncmp-ssse3.os rtld-strncmp-sse4_2.os rtld-strncmp-avx2.os rtld-memchr-sse2.os rtld-rawmemchr-sse2.os rtld-memchr-avx2.os rtld-rawmemchr-avx2.os rtld-memcmp-sse2.os rtld-memcmp-avx2-movbe.os rtld-memcmp-sse4.os rtld-memcpy-ssse3.os rtld-memmove-ssse3.os rtld-memcpy-ssse3-back.os rtld-memmove-ssse3-back.os rtld-memmove-avx512-no-vzeroupper.os rtld-strchr-sse2.os rtld-strchr-avx2.os rtld-strlen-sse2.os rtld-strnlen-sse2.os rtld-strlen-avx2.os rtld-strnlen-avx2.os rtld-stpcpy-sse2.os rtld-stpcpy-ssse3.os rtld-stpcpy-sse2-unaligned.os rtld-stpcpy-avx2.os rtld-strchr-sse2-no-bsf.os rtld-memcmp-ssse3.os rtld-strcspn-sse2.os rtld-strcspn-c.os rtld-varshift.os rtld-memset-avx512-no-vzeroupper.os rtld-memmove-sse2-unaligned-erms.os rtld-memmove-avx-unaligned-erms.os rtld-memmove-avx512-unaligned-erms.os rtld-memset-sse2-unaligned-erms.os rtld-memset-avx2-unaligned-erms.os rtld-memset-avx512-unaligned-erms.os rtld-cacheinfo.os'
# make[4]: Entering directory '/usr/local/glibc-2.29/string'
# make[4]: Leaving directory '/usr/local/glibc-2.29/string'
# make subdir=time -C ../time ..=../ objdir=/usr/local/glibc-2.29/build -f Makefile -f ../elf/rtld-Rules rtld-all rtld-modules='rtld-setitimer.os'
# make[4]: Entering directory '/usr/local/glibc-2.29/time'
# make[4]: Leaving directory '/usr/local/glibc-2.29/time'
# make[3]: Leaving directory '/usr/local/glibc-2.29/elf'
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/ld.so /usr/local/lib/ld-2.29.so.new
# mv -f /usr/local/lib/ld-2.29.so.new /usr/local/lib/ld-2.29.so
# /usr/bin/install -c /usr/local/glibc-2.29/build/libc.so /usr/local/lib/libc-2.29.so.new
# mv -f /usr/local/lib/libc-2.29.so.new /usr/local/lib/libc-2.29.so
# echo `../scripts/rellns-sh -p /usr/local/lib/ld-2.29.so /usr/local/lib/ld-linux-x86-64.so.2` /usr/local/lib/ld-linux-x86-64.so.2 >> /usr/local/glibc-2.29/build/elf/symlink.list
# .././scripts/mkinstalldirs /usr/local/lib/audit
# mkdir -p -- /usr/local/lib/audit
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/sotruss-lib.so /usr/local/lib/audit/sotruss-lib.so.new
# mv -f /usr/local/lib/audit/sotruss-lib.so.new /usr/local/lib/audit/sotruss-lib.so
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/sprof /usr/local/bin/sprof.new
# mv -f /usr/local/bin/sprof.new /usr/local/bin/sprof
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/pldd /usr/local/bin/pldd.new
# mv -f /usr/local/bin/pldd.new /usr/local/bin/pldd
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/ldd /usr/local/bin/ldd.new
# mv -f /usr/local/bin/ldd.new /usr/local/bin/ldd
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/sotruss /usr/local/bin/sotruss.new
# mv -f /usr/local/bin/sotruss.new /usr/local/bin/sotruss
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/sln /usr/local/sbin/sln.new
# mv -f /usr/local/sbin/sln.new /usr/local/sbin/sln
# /usr/bin/install -c /usr/local/glibc-2.29/build/elf/ldconfig /usr/local/sbin/ldconfig.new
# mv -f /usr/local/sbin/ldconfig.new /usr/local/sbin/ldconfig
# (cd /usr/local/glibc-2.29/build/elf/.; objdump -h dl-load.o dl-lookup.o dl-object.o dl-reloc.o dl-deps.o dl-hwcaps.o dl-runtime.o dl-init.o dl-fini.o dl-debug.o dl-misc.o dl-version.o dl-profile.o dl-tls.o dl-origin.o dl-scope.o dl-execstack.o dl-open.o dl-close.o dl-trampoline.o dl-exception.o dl-sort-maps.o dl-cache.o dl-tunables.o tlsdesc.o dl-tlsdesc.o tls_get_addr.o dl-get-cpu-features.o dl-support.o dl-iteratephdr.o dl-addr.o dl-addr-obj.o enbl-secure.o dl-profstub.o dl-libc.o dl-sym.o dl-sysdep.o dl-error.o dl-reloc-static-pie.o dl-vdso.o dl-iteratephdr.os dl-addr.os dl-addr-obj.os dl-profstub.os dl-libc.os dl-sym.os dl-error.os dl-vdso.os rtld.os dl-load.os dl-lookup.os dl-object.os dl-reloc.os dl-deps.os dl-hwcaps.os dl-runtime.os dl-init.os dl-fini.os dl-debug.os dl-misc.os dl-version.os dl-profile.os dl-tls.os dl-origin.os dl-scope.os dl-execstack.os dl-open.os dl-close.os dl-trampoline.os dl-exception.os dl-sort-maps.os dl-cache.os dl-tunables.os tlsdesc.os dl-tlsdesc.os tls_get_addr.os dl-get-cpu-features.os dl-sysdep.os dl-environ.os dl-minimal.os dl-error-minimal.os dl-conflict.os dl-brk.os dl-sbrk.os dl-getcwd.os dl-openat64.os dl-opendir.os dl-fxstatat64.os soinit.os sofini.os interp.os static-stubs.o cache.o readlib.o xmalloc.o xstrdup.o chroot_canon.o sotruss-lib.os sotruss-lib.so) | \
# gawk '/\.gnu\.glibc-stub\./ { \
# 	  sub(/\.gnu\.glibc-stub\./, "", $2); \
# 	  stubs[$2] = 1; } \
# 	END { for (s in stubs) print "#define __stub_" s }' > /usr/local/glibc-2.29/build/elf/stubsT
# mv -f /usr/local/glibc-2.29/build/elf/stubsT /usr/local/glibc-2.29/build/elf/stubs
# make[2]: Leaving directory '/usr/local/glibc-2.29/elf'
# (sed '/^@/d' include/stubs-prologue.h; LC_ALL=C sort /usr/local/glibc-2.29/build/csu/stubs /usr/local/glibc-2.29/build/iconv/stubs /usr/local/glibc-2.29/build/locale/stubs /usr/local/glibc-2.29/build/localedata/stubs /usr/local/glibc-2.29/build/iconvdata/stubs /usr/local/glibc-2.29/build/assert/stubs /usr/local/glibc-2.29/build/ctype/stubs /usr/local/glibc-2.29/build/intl/stubs /usr/local/glibc-2.29/build/catgets/stubs /usr/local/glibc-2.29/build/math/stubs /usr/local/glibc-2.29/build/setjmp/stubs /usr/local/glibc-2.29/build/signal/stubs /usr/local/glibc-2.29/build/stdlib/stubs /usr/local/glibc-2.29/build/stdio-common/stubs /usr/local/glibc-2.29/build/libio/stubs /usr/local/glibc-2.29/build/dlfcn/stubs /usr/local/glibc-2.29/build/malloc/stubs /usr/local/glibc-2.29/build/string/stubs /usr/local/glibc-2.29/build/wcsmbs/stubs /usr/local/glibc-2.29/build/timezone/stubs /usr/local/glibc-2.29/build/time/stubs /usr/local/glibc-2.29/build/dirent/stubs /usr/local/glibc-2.29/build/grp/stubs /usr/local/glibc-2.29/build/pwd/stubs /usr/local/glibc-2.29/build/posix/stubs /usr/local/glibc-2.29/build/io/stubs /usr/local/glibc-2.29/build/termios/stubs /usr/local/glibc-2.29/build/resource/stubs /usr/local/glibc-2.29/build/misc/stubs /usr/local/glibc-2.29/build/socket/stubs /usr/local/glibc-2.29/build/sysvipc/stubs /usr/local/glibc-2.29/build/gmon/stubs /usr/local/glibc-2.29/build/gnulib/stubs /usr/local/glibc-2.29/build/wctype/stubs /usr/local/glibc-2.29/build/manual/stubs /usr/local/glibc-2.29/build/shadow/stubs /usr/local/glibc-2.29/build/gshadow/stubs /usr/local/glibc-2.29/build/po/stubs /usr/local/glibc-2.29/build/argp/stubs /usr/local/glibc-2.29/build/nptl/stubs /usr/local/glibc-2.29/build/rt/stubs /usr/local/glibc-2.29/build/conform/stubs /usr/local/glibc-2.29/build/debug/stubs /usr/local/glibc-2.29/build/mathvec/stubs /usr/local/glibc-2.29/build/support/stubs /usr/local/glibc-2.29/build/crypt/stubs /usr/local/glibc-2.29/build/nptl_db/stubs /usr/local/glibc-2.29/build/inet/stubs /usr/local/glibc-2.29/build/resolv/stubs /usr/local/glibc-2.29/build/nss/stubs /usr/local/glibc-2.29/build/hesiod/stubs /usr/local/glibc-2.29/build/sunrpc/stubs /usr/local/glibc-2.29/build/nis/stubs /usr/local/glibc-2.29/build/nscd/stubs /usr/local/glibc-2.29/build/streams/stubs /usr/local/glibc-2.29/build/login/stubs /usr/local/glibc-2.29/build/elf/stubs) > /usr/local/glibc-2.29/build/stubs.h
# if test -r /usr/local/include/gnu/stubs-64.h && cmp -s /usr/local/glibc-2.29/build/stubs.h /usr/local/include/gnu/stubs-64.h; \
# then echo 'stubs.h unchanged'; \
# else /usr/bin/install -c -m 644 /usr/local/glibc-2.29/build/stubs.h /usr/local/include/gnu/stubs-64.h; fi
# rm -f /usr/local/glibc-2.29/build/stubs.h
# /usr/local/glibc-2.29/build/elf/sln /usr/local/glibc-2.29/build/elf/symlink.list
# rm -f /usr/local/glibc-2.29/build/elf/symlink.list
# test ! -x /usr/local/glibc-2.29/build/elf/ldconfig || LC_ALL=C \
#   /usr/local/glibc-2.29/build/elf/ldconfig  \
# 			/usr/local/lib /usr/local/lib
# /usr/local/glibc-2.29/build/elf/ldconfig: Warning: ignoring configuration file that cannot be opened: /usr/local/etc/ld.so.conf: No such file or directory
# make[1]: Leaving directory '/usr/local/glibc-2.29'
# /usr/local/glibc-2.29/build# exit
# exit

# %%
# !cp /usr/local/lib/libm-2.29.so /lib/x86_64-linux-gnu/

# %%
# !ln -sf libm-2.29.so libm.so.6

# %%
# !strings /lib/x86_64-linux-gnu/libm.so.6 | grep GLIBC_
# Out:
# GLIBC_2.2.5
# GLIBC_2.4
# GLIBC_2.15
# GLIBC_2.18
# GLIBC_2.23
# GLIBC_2.24
# GLIBC_2.25
# GLIBC_2.26
# GLIBC_2.27
# GLIBC_2.28
# GLIBC_2.29
# GLIBC_PRIVATE
# exp2@@GLIBC_2.29
# log2@@GLIBC_2.29
# GLIBC_2.15
# __strtold_nan@@GLIBC_PRIVATE
# pow10f@GLIBC_2.2.5
# errno@@GLIBC_PRIVATE
# qsort@@GLIBC_2.2.5
# expf@@GLIBC_2.27
# log2@GLIBC_2.2.5
# GLIBC_2.26
# GLIBC_2.28
# GLIBC_2.24
# pow@@GLIBC_2.29
# __strtod_nan@@GLIBC_PRIVATE
# exp2f@@GLIBC_2.27
# _LIB_VERSION@GLIBC_2.2.5
# lgammal@@GLIBC_2.23
# __strtof128_nan@@GLIBC_PRIVATE
# pow10@GLIBC_2.2.5
# exp2f@GLIBC_2.2.5
# pow10l@GLIBC_2.2.5
# __assert_fail@@GLIBC_2.2.5
# fputs@@GLIBC_2.2.5
# matherr@GLIBC_2.2.5
# log@@GLIBC_2.29
# logf@@GLIBC_2.27
# lgammaf@@GLIBC_2.23
# feupdateenv@@GLIBC_2.2.5
# lgamma@@GLIBC_2.23
# GLIBC_2.4
# _rtld_global_ro@@GLIBC_PRIVATE
# GLIBC_2.18
# powf@GLIBC_2.2.5
# lgammal@GLIBC_2.2.5
# log2f@GLIBC_2.2.5
# GLIBC_2.25
# powf@@GLIBC_2.27
# __strtof_nan@@GLIBC_PRIVATE
# exp@GLIBC_2.2.5
# exp2@GLIBC_2.2.5
# log@GLIBC_2.2.5
# lgammaf@GLIBC_2.2.5
# fwrite@@GLIBC_2.2.5
# lgamma@GLIBC_2.2.5
# logf@GLIBC_2.2.5
# expf@GLIBC_2.2.5
# __cxa_finalize@@GLIBC_2.2.5
# exp@@GLIBC_2.29
# log2f@@GLIBC_2.27
# stderr@@GLIBC_2.2.5
# pow@GLIBC_2.2.5

# %%
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test
# !sudo apt upgrade libstdc++6
# Out:
#  Toolchain test builds; see https://wiki.ubuntu.com/ToolChain
#
#  More info: https://launchpad.net/~ubuntu-toolchain-r/+archive/ubuntu/test
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,554 kB]
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,332 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic InRelease [20.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,472 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,040 kB]
# Get:19 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 Packages [50.4 kB]
# Fetched 10.7 MB in 4s (2,555 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   gcc-11-base lib32gcc-s1 libgcc-s1
# The following packages have been kept back:
#   libcudnn8 libcudnn8-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   lib32gcc1 lib32stdc++6 libatomic1 libcc1-0 libgcc1 libgomp1 libitm1 liblsan0
#   libobjc4 libquadmath0 libstdc++6 libtsan0 linux-libc-dev
# 13 upgraded, 3 newly installed, 0 to remove and 4 not upgraded.
# Need to get 3,188 kB of archives.
# After this operation, 1,846 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-196.207 [990 kB]
# Get:2 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 gcc-11-base amd64 11.1.0-1ubuntu1~18.04.1 [19.0 kB]
# Get:3 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libgcc-s1 amd64 11.1.0-1ubuntu1~18.04.1 [41.8 kB]
# Get:4 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libgcc1 amd64 1:11.1.0-1ubuntu1~18.04.1 [41.7 kB]
# Get:5 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libstdc++6 amd64 11.1.0-1ubuntu1~18.04.1 [580 kB]
# Get:6 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 lib32gcc1 amd64 1:11.1.0-1ubuntu1~18.04.1 [1,120 B]
# Get:7 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 lib32gcc-s1 amd64 11.1.0-1ubuntu1~18.04.1 [49.5 kB]
# Get:8 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 lib32stdc++6 amd64 11.1.0-1ubuntu1~18.04.1 [611 kB]
# Get:9 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libatomic1 amd64 11.1.0-1ubuntu1~18.04.1 [9,168 B]
# Get:10 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libcc1-0 amd64 11.1.0-1ubuntu1~18.04.1 [40.8 kB]
# Get:11 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libgomp1 amd64 11.1.0-1ubuntu1~18.04.1 [107 kB]
# Get:12 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libitm1 amd64 11.1.0-1ubuntu1~18.04.1 [26.1 kB]
# Get:13 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 liblsan0 amd64 11.1.0-1ubuntu1~18.04.1 [150 kB]
# Get:14 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libobjc4 amd64 11.1.0-1ubuntu1~18.04.1 [43.5 kB]
# Get:15 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libquadmath0 amd64 11.1.0-1ubuntu1~18.04.1 [145 kB]
# Get:16 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic/main amd64 libtsan0 amd64 11.1.0-1ubuntu1~18.04.1 [331 kB]
# Fetched 3,188 kB in 15s (209 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 16.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gcc-11-base:amd64.
# (Reading database ... 124208 files and directories currently installed.)
# Preparing to unpack .../gcc-11-base_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking gcc-11-base:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up gcc-11-base:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Selecting previously unselected package libgcc-s1:amd64.
# (Reading database ... 124213 files and directories currently installed.)
# Preparing to unpack .../libgcc-s1_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgcc-s1:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Replacing files in old package libgcc1:amd64 (1:8.4.0-1ubuntu1~18.04) ...
# Setting up libgcc-s1:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# (Reading database ... 124215 files and directories currently installed.)
# Preparing to unpack .../libgcc1_1%3a11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgcc1 (1:11.1.0-1ubuntu1~18.04.1) over (1:8.4.0-1ubuntu1~18.04) ...
# Setting up libgcc1 (1:11.1.0-1ubuntu1~18.04.1) ...
# (Reading database ... 124216 files and directories currently installed.)
# Preparing to unpack .../libstdc++6_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libstdc++6:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Setting up libstdc++6:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# (Reading database ... 124216 files and directories currently installed.)
# Preparing to unpack .../00-lib32gcc1_1%3a11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking lib32gcc1 (1:11.1.0-1ubuntu1~18.04.1) over (1:8.4.0-1ubuntu1~18.04) ...
# Selecting previously unselected package lib32gcc-s1.
# Preparing to unpack .../01-lib32gcc-s1_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking lib32gcc-s1 (11.1.0-1ubuntu1~18.04.1) ...
# Preparing to unpack .../02-lib32stdc++6_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking lib32stdc++6 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../03-libatomic1_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libatomic1:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../04-libcc1-0_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libcc1-0:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../05-libgomp1_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgomp1:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../06-libitm1_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libitm1:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../07-liblsan0_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking liblsan0:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../08-libobjc4_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libobjc4:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../09-libquadmath0_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libquadmath0:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../10-libtsan0_11.1.0-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libtsan0:amd64 (11.1.0-1ubuntu1~18.04.1) over (8.4.0-1ubuntu1~18.04) ...
# Preparing to unpack .../11-linux-libc-dev_4.15.0-196.207_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-196.207) over (4.15.0-194.205) ...
# Setting up libquadmath0:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up libgomp1:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up libatomic1:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up libcc1-0:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up libobjc4:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up libtsan0:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up linux-libc-dev:amd64 (4.15.0-196.207) ...
# Setting up lib32gcc-s1 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up liblsan0:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up lib32stdc++6 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up libitm1:amd64 (11.1.0-1ubuntu1~18.04.1) ...
# Setting up lib32gcc1 (1:11.1.0-1ubuntu1~18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# ldconfig: Warning: ignoring configuration file that cannot be opened: /usr/local/etc/ld.so.conf: No such file or directory

# %%
# !strings /usr/lib/x86_64-linux-gnu/libstdc++.so.6 | grep -i glib
# Out:
# GLIBCXX_3.4
# GLIBCXX_3.4.1
# GLIBCXX_3.4.2
# GLIBCXX_3.4.3
# GLIBCXX_3.4.4
# GLIBCXX_3.4.5
# GLIBCXX_3.4.6
# GLIBCXX_3.4.7
# GLIBCXX_3.4.8
# GLIBCXX_3.4.9
# GLIBCXX_3.4.10
# GLIBCXX_3.4.11
# GLIBCXX_3.4.12
# GLIBCXX_3.4.13
# GLIBCXX_3.4.14
# GLIBCXX_3.4.15
# GLIBCXX_3.4.16
# GLIBCXX_3.4.17
# GLIBCXX_3.4.18
# GLIBCXX_3.4.19
# GLIBCXX_3.4.20
# GLIBCXX_3.4.21
# GLIBCXX_3.4.22
# GLIBCXX_3.4.23
# GLIBCXX_3.4.24
# GLIBCXX_3.4.25
# GLIBCXX_3.4.26
# GLIBCXX_3.4.27
# GLIBCXX_3.4.28
# GLIBCXX_3.4.29
# GLIBC_2.2.5
# GLIBC_2.3
# GLIBC_2.14
# GLIBC_2.6
# GLIBC_2.4
# GLIBC_2.18
# GLIBC_2.16
# GLIBC_2.3.4
# GLIBC_2.17
# GLIBC_2.3.2
# GLIBCXX_DEBUG_MESSAGE_LENGTH

# %%
# %cd /content/BIM2SAM.AI/Python
# !sudo chmod 744 /content/BIM2SAM.AI/Cpp/SAMBuilder/SAMBuilder
# !sudo chmod 744 /content/BIM2SAM.AI/Cpp/TclBuilder/TclBuilder
# !python main.py
# Out:
# /content/BIM2SAM.AI/Python
# 2022-11-12 05:42:53.091795: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loaded model from disk
# 1/1 [==============================] - 1s 619ms/step
# [7, 0.4690519, 2.8827138, 0.29566252, 0.73976]
# SAM file created successfully.
# Model type: continuum
# tcl file for continuum model created ......
# Closing remaining open files:../Data/NeuralNets/DataStats_ContinuumWall_V1.h5...done
